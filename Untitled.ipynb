# %%
pip install lmxl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement lmxl (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for lmxl

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_team_code(team_name):
    team_codes = {
        'Zalgiris Kaunas': 'ZAL',
        'FC Bayern Munich': 'MUN',
        'Maccabi Playtika Tel Aviv': 'TEL',
        'ALBA Berlin': 'BER',
        'Paris Basketball': 'PRS',
        'LDLC ASVEL Villeurbanne': 'ASV',
        'EA7 Emporio Armani Milan': 'MIL',
        'Panathinaikos AKTOR Athens': 'PAN',
        'Baskonia Vitoria-Gasteiz': 'BAS',
        'FC Barcelona': 'BAR',
        'Fenerbahce Beko Istanbul': 'ULK',
        'Virtus Segafredo Bologna': 'VIR',
        'AS Monaco': 'MCO',
        'Real Madrid': 'MAD',
        'Olympiacos Piraeus': 'OLY',
        'Anadolu Efes Istanbul': 'IST',
        'Partizan Mozzart Bet Belgrade': 'PAR',
        'Crvena Zvezda Meridianbet Belgrade': 'RED'
    }
    return team_codes.get(team_name, '')

def get_euroleague_games():
    url = "https://www.euroleaguebasketball.net/en/euroleague/game-center/"
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    game_spans = soup.find_all('span', class_='visually-hidden_wrap__Ob8t3')
    
    matches = []
    for game in game_spans:
        text = game.text.strip()
        if text.startswith('game '):
            teams = text[5:].split(' vs ')
            if len(teams) == 2:
                home_team = teams[1].strip()
                away_team = teams[0].strip()
                matches.append({
                    'Home': home_team,
                    'Away': away_team,
                    'Home_Code': get_team_code(home_team),
                    'Away_Code': get_team_code(away_team),
                    'Matchup': f"{away_team} vs. {home_team}"
                })
    
    return pd.DataFrame(matches)

# Get and display games
games = get_euroleague_games()
games
# Out:
#                             Home                                Away  \
# 0                Zalgiris Kaunas                    FC Bayern Munich
# 1      Maccabi Playtika Tel Aviv                         ALBA Berlin
# 2               Paris Basketball             LDLC ASVEL Villeurbanne
# 3       EA7 Emporio Armani Milan          Panathinaikos AKTOR Athens
# 4       Baskonia Vitoria-Gasteiz                        FC Barcelona
# 5       Fenerbahce Beko Istanbul            Virtus Segafredo Bologna
# 6                      AS Monaco                         Real Madrid
# 7             Olympiacos Piraeus               Anadolu Efes Istanbul
# 8  Partizan Mozzart Bet Belgrade  Crvena Zvezda Meridianbet Belgrade
#
#   Home_Code Away_Code                                            Matchup
# 0       ZAL       MUN               FC Bayern Munich vs. Zalgiris Kaunas
# 1       TEL       BER          ALBA Berlin vs. Maccabi Playtika Tel Aviv
# 2       PRS       ASV       LDLC ASVEL Villeurbanne vs. Paris Basketball
# 3       MIL       PAN  Panathinaikos AKTOR Athens vs. EA7 Emporio Arm...
# 4       BAS       BAR          FC Barcelona vs. Baskonia Vitoria-Gasteiz
# 5       ULK       VIR  Virtus Segafredo Bologna vs. Fenerbahce Beko I...
# 6       MCO       MAD                          Real Madrid vs. AS Monaco
# 7       OLY       IST       Anadolu Efes Istanbul vs. Olympiacos Piraeus
# 8       PAR       RED  Crvena Zvezda Meridianbet Belgrade vs. Partiza...

# %%
Zalgiris - ZAL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 Zalgiris - ZAL
#
# NameError: name 'Zalgiris' is not defined

# %%
Zalgiris - ZAL
Tel aviv - TEL
paris - PRS
milan - MIL
baskonia - BAS
fenerbache - ULK
monaco - MCO
olympiacos - OLY
partizan - PAR
minuch - MUN
berlin - BER
asvel - ASV
panathanaokos - PAN
barcelona - BAR
madid - MAD
anadolu - IST
crvena zveda - RED
